# %% [markdown]
# # Mapping charter schools

# %% [markdown]
# Authors:
# - Harshayu Girase, URAP research apprentice, Computer Science major, UC Berkeley
# - Serena Jiang, URAP research apprentice, Computer Science major, UC Berkeley
# - Jaren Haber, PhD Candidate, Sociology, UC Berkeley

# %%
# Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from shapely.geometry import Point
import geopandas as gpd

# %%
# Define data file paths
charterfile = './charters_parsed_03-04_no-text_SMALL.csv'
districtfile = './ACS_2016_sd-merged_FULL.csv'
publicfile = './pub_merged_2015_acs.csv'
shapefile = 'district.shp'

district = gpd.read_file(shapefile) # Create shapefile DF with only geometric data (for general use)

# %% [markdown]
# ## Define helper functions

# %%
def refresh_data():
    '''Loads data from file, undoing any bounding boxes, etc. 
    Great for making a fresh start when plotting a new area.
    
    Also merges geometric data from shapefile DF into full school district DF.
    To do this, first creates a common identifier across these DFs by modifying district 'Qualifying Name' 
    so it lines up with the district shapefile.'''
    
    global charterDF, district_df, publicDF
    
    # Import data:
    charterDF = pd.read_csv(charterfile, low_memory=False) # Charter school data
    publicDF = pd.read_csv(publicfile, low_memory=False) # Public school data
    districtDF = pd.read_csv(districtfile, encoding='latin-1', low_memory=False) # School district data
    
    # Merge shapefile with district file:
    districtDF['NAME'] = districtDF['Qualifying Name'].apply(lambda x: ",".join(x.split(",")[:-1]).strip())
    district_df = pd.merge(districtDF, district, on="NAME") 
    district_df = gpd.GeoDataFrame(district_df)
    
    # Create geometry for charter schools:
    charterDF['geometry'] = charterDF[['LONGCODE', 'LATCODE']].apply(lambda row: Point(row["LONGCODE"], row["LATCODE"]), axis=1) # Use GeoPandas to create Point class for each school
    charterDF = gpd.GeoDataFrame(charterDF)
    charterDF.crs = {'init' :'epsg:4326'}
    charterDF = charterDF.to_crs(district.crs)

    # TO DO: Improve projection so it layers the multiple shapefiles into a single map--to get rid of blank/white spaces

# %%
def createBoundingBox(boundingBox):
    '''Pre-requisite function for creating maps within a bounded area or "boundingBox".
    This function accomplishes this by limiting the relevant DataFrames to only those data points
    located within the bounded area defined in the two points indicated in the function call. 
    This allows the plot() function to map the entire DF (which it is designed to do).
    
    Input is a list of four numbers: [upperleft longitude, upperleft latitude, lowerleft longitude, lowerleft latitude].
    No direct output--modifies DFs.'''
    
    global publicDF
    global charterDF
    global district_df
    
    ULLON = boundingBox[0]
    ULLAT = boundingBox[1]
    LRLON = boundingBox[2]
    LRLAT = boundingBox[3]
    
    publicDF = publicDF[publicDF['LON1516']>ULLON]
    publicDF= publicDF[publicDF['LAT1516']<ULLAT]
    publicDF = publicDF[publicDF['LON1516']<LRLON]
    publicDF = publicDF[publicDF['LAT1516']>LRLAT]
    charterDF = charterDF[charterDF['LONGCODE']>ULLON]
    charterDF = charterDF[charterDF['LATCODE']<ULLAT]
    charterDF = charterDF[charterDF['LONGCODE']<LRLON]
    charterDF = charterDF[charterDF['LATCODE']>LRLAT]

    validDistricts = "" # String of all districts within bounded area, appended one at a time
    
    # Iterate over publicDF, adding each valid district into string validDistricts:
    for index, row in publicDF.iterrows():
        try:
            validDistricts += str(int(publicDF["LEAID"][index])) + " " # Grab LEAIDs for valid districts, indexing by column and then row
        except Exception as e:
            continue

    dropList = []
    
    for index, row in district_df.iterrows():
        try:
            if ((str(int(district_df["FIPS"][index]))) not in validDistricts):
                dropList.append(index)
        except Exception as e:
            continue
            
    district_df = district_df.drop(dropList) # Drop districts not in bounding box
    
    return

# %%
def plot(district_col, whole=True, state="", ab=""):
    '''Maps school districts in given area as chloropleth map shaded by variable district_col, 
    showing points for schools based on latitude/longitude and ess_lean. 
    Points are shaded such that blue is lower in ess_lean and red is higher.
    
    The only required parameter is district_col, the variable/column by which to shade school districts. 
    If bounding boxes are being used, ignore the other parameters below. 
    Example function call: 
    plot('Median household income (In 2014 Inflation Adjusted Dollars')
    
    Other parameters:
    whole = whether or not to map entire country (Boolean). If False, need BOTH of the following:
    state = whether to map a particular state
    ab = single state abbreviation, e.g. FL
    
    Leaving 'whole' as False and giving a state will plot that state only;
    Leaving 'whole' as False and giving no state will plot the whole US.
    
    Note on working with these functions:
    To use the single-state functionality of this function AFTER creating a bounding box, 
    rerun the notebook in order to recreate the full dataframes.'''
    
    
    figsize = (14, 7) if whole else (10,7) # Define scale for US (if whole) or single state (if not)
    fig, ax = plt.subplots(figsize=figsize)
    tempdistrict_df = district_df # Make temporary DF for within function
    
    # If mapping just one state, define state abbreviation column name:
    if not whole:
        tempdistrict_df = tempdistrict_df[tempdistrict_df['State/U.S.-Abbreviation (USPS)'] == ab]
        
    tempdistrict_df = tempdistrict_df[[district_col, 'geometry']].dropna() # Drop if no coordinates
    tempdistrict_df[district_col] = tempdistrict_df[district_col].apply(pd.to_numeric,downcast='float') # Convert to most efficient float type
    
    # Plot layers of map:
    tempdistrict_df.plot(ax = ax, column=district_col, cmap='PiYG', linewidth=0, legend=True) # Plot shaded areas
    charterDF[whole | (charterDF['STATENAME'] == state)].plot(ax = ax, cmap="coolwarm", column="ess_lean", markersize=20, linewidth=0, legend=True) # Plot points
    # Note: cmap = shading style (e.g., PiYG = pink to green)
    
    ax.legend()
    plt.show()
    
    return

# %% [markdown]
# ## Plotting

# %%
refresh_data() # Load in data!

# %%
# Example of using mapping function:
bayArea = [-123.26482826886195, 38.66436310541212, -121.06756264386195, 37.12821658249273]
createBoundingBox(bayArea)
district_df
# Out:
#          FIPS                                       Name of Area  \
# 1453  0600019         Dublin Unified School District, California
# 1454  0600020     Pleasanton Unified School District, California
# 1455  0600021     Sunol Glen Unified School District, California
# 1465  0600034        Windsor Unified School District, California
# 1467  0600036        Natomas Unified School District, California
# 1474  0600044     Healdsburg Unified School District, California
# 1477  0600047          Tracy Unified School District, California
# 1497  0601332    Twin Rivers Unified School District, California
# 1500  0601410  Lammersville Joint Unified School District, Ca...
# 1506  0601770   Alameda City Unified School District, California
# 1507  0601860    Albany City Unified School District, California
# 1513  0602850        Antioch Unified School District, California
# 1525  0604620        Benicia Unified School District, California
# 1526  0604740       Berkeley Unified School District, California
# 1537  0606780       Cabrillo Unified School District, California
# 1541  0607020  Calistoga Joint Unified School District, Calif...
# 1546  0607800  Castro Valley Unified School District, California
# 1565  0609940  Cotati-Rohnert Park Unified School District, C...
# 1569  0610620    Davis Joint Unified School District, California
# 1575  0611280          Dixon Unified School District, California
# 1582  0612330      Elk Grove Unified School District, California
# 1583  0612630          Emery Unified School District, California
# 1584  0612840        Escalon Unified School District, California
# 1586  0613360  Fairfield-Suisun Unified School District, Cali...
# 1589  0613890  Folsom-Cordova Unified School District, Califo...
# 1593  0614400        Fremont Unified School District, California
# 1603  0616740        Hayward Unified School District, California
# 1609  0618990     John Swett Unified School District, California
# 1617  0620220  La Honda-Pescadero Unified School District, Ca...
# 1623  0621690        Lincoln Unified School District, California
# ...       ...                                                ...
# 1664  0627060         Newark Unified School District, California
# 1665  0627200  Newman-Crows Landing Unified School District, ...
# 1669  0627720         Novato Unified School District, California
# 1671  0628050        Oakland Unified School District, California
# 1679  0629610      Palo Alto Unified School District, California
# 1686  0630030  Patterson Joint Unified School District, Calif...
# 1687  0630330  Piedmont City Unified School District, California
# 1689  0630600      Pittsburg Unified School District, California
# 1700  0632550  West Contra Costa Unified School District, Cal...
# 1702  0632880          Ripon Unified School District, California
# 1703  0633110  River Delta Joint Unified School District, Cal...
# 1707  0633840  Sacramento City Unified School District, Calif...
# 1711  0634410  San Francisco Unified School District, California
# 1714  0634590       San Jose Unified School District, California
# 1715  0634620       San Juan Unified School District, California
# 1716  0634680    San Leandro Unified School District, California
# 1717  0634710    San Lorenzo Unified School District, California
# 1718  0634740  San Lorenzo Valley Unified School District, Ca...
# 1723  0635130  San Ramon Valley Unified School District, Cali...
# 1726  0635430    Santa Clara Unified School District, California
# 1730  0636670      Shoreline Unified School District, California
# 1738  0637200  Sonoma Valley Unified School District, California
# 1740  0637530  South San Francisco Unified School District, C...
# 1744  0637830     St. Helena Unified School District, California
# 1745  0638010       Stockton Unified School District, California
# 1752  0639630         Travis Unified School District, California
# 1757  0640590      Vacaville Unified School District, California
# 1758  0640740   Vallejo City Unified School District, California
# 1770  0642930  Winters Joint Unified School District, California
# 1771  0643080  Woodland Joint Unified School District, Califo...
#
#                                         Qualifying Name  \
# 1453         Dublin Unified School District, California
# 1454     Pleasanton Unified School District, California
# 1455     Sunol Glen Unified School District, California
# 1465        Windsor Unified School District, California
# 1467        Natomas Unified School District, California
# 1474     Healdsburg Unified School District, California
# 1477          Tracy Unified School District, California
# 1497    Twin Rivers Unified School District, California
# 1500  Lammersville Joint Unified School District, Ca...
# 1506   Alameda City Unified School District, California
# 1507    Albany City Unified School District, California
# 1513        Antioch Unified School District, California
# 1525        Benicia Unified School District, California
# 1526       Berkeley Unified School District, California
# 1537       Cabrillo Unified School District, California
# 1541  Calistoga Joint Unified School District, Calif...
# 1546  Castro Valley Unified School District, California
# 1565  Cotati-Rohnert Park Unified School District, C...
# 1569    Davis Joint Unified School District, California
# 1575          Dixon Unified School District, California
# 1582      Elk Grove Unified School District, California
# 1583          Emery Unified School District, California
# 1584        Escalon Unified School District, California
# 1586  Fairfield-Suisun Unified School District, Cali...
# 1589  Folsom-Cordova Unified School District, Califo...
# 1593        Fremont Unified School District, California
# 1603        Hayward Unified School District, California
# 1609     John Swett Unified School District, California
# 1617  La Honda-Pescadero Unified School District, Ca...
# 1623        Lincoln Unified School District, California
# ...                                                 ...
# 1664         Newark Unified School District, California
# 1665  Newman-Crows Landing Unified School District, ...
# 1669         Novato Unified School District, California
# 1671        Oakland Unified School District, California
# 1679      Palo Alto Unified School District, California
# 1686  Patterson Joint Unified School District, Calif...
# 1687  Piedmont City Unified School District, California
# 1689      Pittsburg Unified School District, California
# 1700  West Contra Costa Unified School District, Cal...
# 1702          Ripon Unified School District, California
# 1703  River Delta Joint Unified School District, Cal...
# 1707  Sacramento City Unified School District, Calif...
# 1711  San Francisco Unified School District, California
# 1714       San Jose Unified School District, California
# 1715       San Juan Unified School District, California
# 1716    San Leandro Unified School District, California
# 1717    San Lorenzo Unified School District, California
# 1718  San Lorenzo Valley Unified School District, Ca...
# 1723  San Ramon Valley Unified School District, Cali...
# 1726    Santa Clara Unified School District, California
# 1730      Shoreline Unified School District, California
# 1738  Sonoma Valley Unified School District, California
# 1740  South San Francisco Unified School District, C...
# 1744     St. Helena Unified School District, California
# 1745       Stockton Unified School District, California
# 1752         Travis Unified School District, California
# 1757      Vacaville Unified School District, California
# 1758   Vallejo City Unified School District, California
# 1770  Winters Joint Unified School District, California
# 1771  Woodland Joint Unified School District, Califo...
#
#      State/U.S.-Abbreviation (USPS) Summary Level Geographic Component  \
# 1453                             ca           970                   00
# 1454                             ca           970                   00
# 1455                             ca           970                   00
# 1465                             ca           970                   00
# 1467                             ca           970                   00
# 1474                             ca           970                   00
# 1477                             ca           970                   00
# 1497                             ca           970                   00
# 1500                             ca           970                   00
# 1506                             ca           970                   00
# 1507                             ca           970                   00
# 1513                             ca           970                   00
# 1525                             ca           970                   00
# 1526                             ca           970                   00
# 1537                             ca           970                   00
# 1541                             ca           970                   00
# 1546                             ca           970                   00
# 1565                             ca           970                   00
# 1569                             ca           970                   00
# 1575                             ca           970                   00
# 1582                             ca           970                   00
# 1583                             ca           970                   00
# 1584                             ca           970                   00
# 1586                             ca           970                   00
# 1589                             ca           970                   00
# 1593                             ca           970                   00
# 1603                             ca           970                   00
# 1609                             ca           970                   00
# 1617                             ca           970                   00
# 1623                             ca           970                   00
# ...                             ...           ...                  ...
# 1664                             ca           970                   00
# 1665                             ca           970                   00
# 1669                             ca           970                   00
# 1671                             ca           970                   00
# 1679                             ca           970                   00
# 1686                             ca           970                   00
# 1687                             ca           970                   00
# 1689                             ca           970                   00
# 1700                             ca           970                   00
# 1702                             ca           970                   00
# 1703                             ca           970                   00
# 1707                             ca           970                   00
# 1711                             ca           970                   00
# 1714                             ca           970                   00
# 1715                             ca           970                   00
# 1716                             ca           970                   00
# 1717                             ca           970                   00
# 1718                             ca           970                   00
# 1723                             ca           970                   00
# 1726                             ca           970                   00
# 1730                             ca           970                   00
# 1738                             ca           970                   00
# 1740                             ca           970                   00
# 1744                             ca           970                   00
# 1745                             ca           970                   00
# 1752                             ca           970                   00
# 1757                             ca           970                   00
# 1758                             ca           970                   00
# 1770                             ca           970                   00
# 1771                             ca           970                   00
#
#      File Identification Logical Record Number   US Region  \
# 1453               ACSSF               0040098  NaN    NaN
# 1454               ACSSF               0040099  NaN    NaN
# 1455               ACSSF               0040100  NaN    NaN
# 1465               ACSSF               0040110  NaN    NaN
# 1467               ACSSF               0040112  NaN    NaN
# 1474               ACSSF               0040119  NaN    NaN
# 1477               ACSSF               0040122  NaN    NaN
# 1497               ACSSF               0040142  NaN    NaN
# 1500               ACSSF               0040145  NaN    NaN
# 1506               ACSSF               0040152  NaN    NaN
# 1507               ACSSF               0040153  NaN    NaN
# 1513               ACSSF               0040159  NaN    NaN
# 1525               ACSSF               0040171  NaN    NaN
# 1526               ACSSF               0040172  NaN    NaN
# 1537               ACSSF               0040183  NaN    NaN
# 1541               ACSSF               0040187  NaN    NaN
# 1546               ACSSF               0040192  NaN    NaN
# 1565               ACSSF               0040212  NaN    NaN
# 1569               ACSSF               0040216  NaN    NaN
# 1575               ACSSF               0040222  NaN    NaN
# 1582               ACSSF               0040229  NaN    NaN
# 1583               ACSSF               0040230  NaN    NaN
# 1584               ACSSF               0040231  NaN    NaN
# 1586               ACSSF               0040233  NaN    NaN
# 1589               ACSSF               0040237  NaN    NaN
# 1593               ACSSF               0040241  NaN    NaN
# 1603               ACSSF               0040251  NaN    NaN
# 1609               ACSSF               0040257  NaN    NaN
# 1617               ACSSF               0040265  NaN    NaN
# 1623               ACSSF               0040271  NaN    NaN
# ...                  ...                   ...  ...    ...
# 1664               ACSSF               0040313  NaN    NaN
# 1665               ACSSF               0040314  NaN    NaN
# 1669               ACSSF               0040318  NaN    NaN
# 1671               ACSSF               0040320  NaN    NaN
# 1679               ACSSF               0040328  NaN    NaN
# 1686               ACSSF               0040335  NaN    NaN
# 1687               ACSSF               0040336  NaN    NaN
# 1689               ACSSF               0040338  NaN    NaN
# 1700               ACSSF               0040349  NaN    NaN
# 1702               ACSSF               0040351  NaN    NaN
# 1703               ACSSF               0040352  NaN    NaN
# 1707               ACSSF               0040356  NaN    NaN
# 1711               ACSSF               0040360  NaN    NaN
# 1714               ACSSF               0040363  NaN    NaN
# 1715               ACSSF               0040364  NaN    NaN
# 1716               ACSSF               0040365  NaN    NaN
# 1717               ACSSF               0040366  NaN    NaN
# 1718               ACSSF               0040367  NaN    NaN
# 1723               ACSSF               0040372  NaN    NaN
# 1726               ACSSF               0040375  NaN    NaN
# 1730               ACSSF               0040379  NaN    NaN
# 1738               ACSSF               0040387  NaN    NaN
# 1740               ACSSF               0040389  NaN    NaN
# 1744               ACSSF               0040393  NaN    NaN
# 1745               ACSSF               0040394  NaN    NaN
# 1752               ACSSF               0040402  NaN    NaN
# 1757               ACSSF               0040407  NaN    NaN
# 1758               ACSSF               0040408  NaN    NaN
# 1770               ACSSF               0040421  NaN    NaN
# 1771               ACSSF               0040422  NaN    NaN
#
#                             ...                         FUNCSTAT        ALAND  \
# 1453                        ...                                E   35426071.0
# 1454                        ...                                E  102460910.0
# 1455                        ...                                E  244322988.0
# 1465                        ...                                E   79504355.0
# 1467                        ...                                E   95948245.0
# 1474                        ...                                E  145770119.0
# 1477                        ...                                E  504938787.0
# 1497                        ...                                E  114082153.0
# 1500                        ...                                E   60842581.0
# 1506                        ...                                E   27045458.0
# 1507                        ...                                E    4634305.0
# 1513                        ...                                E  102869243.0
# 1525                        ...                                E   81871389.0
# 1526                        ...                                E   27095285.0
# 1537                        ...                                E  277459851.0
# 1541                        ...                                E  242823823.0
# 1546                        ...                                E  177385526.0
# 1565                        ...                                E   38554954.0
# 1569                        ...                                E  329809654.0
# 1575                        ...                                E  504174328.0
# 1582                        ...                                E  850256773.0
# 1583                        ...                                E    3317306.0
# 1584                        ...                                E  415748799.0
# 1586                        ...                                E  612885955.0
# 1589                        ...                                E  232114483.0
# 1593                        ...                                E  200405413.0
# 1603                        ...                                E   83902804.0
# 1609                        ...                                E   52776336.0
# 1617                        ...                                E  352397840.0
# 1623                        ...                                E   29824854.0
# ...                         ...                              ...          ...
# 1664                        ...                                E   36116580.0
# 1665                        ...                                E  961651398.0
# 1669                        ...                                E  154169421.0
# 1671                        ...                                E  144803266.0
# 1679                        ...                                E   71013950.0
# 1686                        ...                                E  931831220.0
# 1687                        ...                                E    4402167.0
# 1689                        ...                                E   67791737.0
# 1700                        ...                                E  159621863.0
# 1702                        ...                                E  139638884.0
# 1703                        ...                                E  879207201.0
# 1707                        ...                                E  175217555.0
# 1711                        ...                                E  121455687.0
# 1714                        ...                                E  122648090.0
# 1715                        ...                                E  196793771.0
# 1716                        ...                                E   30080887.0
# 1717                        ...                                E   28581174.0
# 1718                        ...                                E  235764611.0
# 1723                        ...                                E  276720424.0
# 1726                        ...                                E  105998991.0
# 1730                        ...                                E  611141401.0
# 1738                        ...                                E  311653474.0
# 1740                        ...                                E   29539476.0
# 1744                        ...                                E  730933164.0
# 1745                        ...                                E  146392980.0
# 1752                        ...                                E  114770909.0
# 1757                        ...                                E  268981179.0
# 1758                        ...                                E  107573628.0
# 1770                        ...                                E  331379360.0
# 1771                        ...                                E  799200760.0
#
#            AWATER     INTPTLAT      INTPTLON    GISJOIN     Shape_Leng  \
# 1453          0.0  +37.7153770  -121.9104967  G06000019   37799.106445
# 1454     391116.0  +37.6649739  -121.8867095  G06000020   58631.121814
# 1455    2809642.0  +37.5511338  -121.8054596  G06000021   76479.473027
# 1465     477276.0  +38.5491930  -122.8050545  G06000034   52828.730908
# 1467    2823304.0  +38.6670737  -121.5671691  G06000036   54828.306707
# 1474     345713.0  +38.6373850  -122.8884599  G06000044   78342.842100
# 1477   27600762.0  +37.8910619  -121.4707749  G06000047  163699.130232
# 1497    1389497.0  +38.6727995  -121.3842225  G06001332   89683.692314
# 1500      69569.0  +37.7460948  -121.5230350  G06001410   36837.286594
# 1506   32778370.0  +37.7419107  -122.2599139  G06001770   48864.867584
# 1507    9523833.0  +37.8906499  -122.3181164  G06001860   13831.201615
# 1513    6284270.0  +37.9789846  -121.8066181  G06002850   53937.631124
# 1525   12200035.0  +38.0927119  -122.1381052  G06004620   50644.264077
# 1526   18715614.0  +37.8669717  -122.2991474  G06004740   37391.075458
# 1537  196251016.0  +37.4377371  -122.4368377  G06006780  110056.297649
# 1541     396255.0  +38.6348225  -122.6150507  G06007020  109581.438271
# 1546    4276387.0  +37.7196716  -122.0463454  G06007800   99453.037266
# 1565      29015.0  +38.3392564  -122.7071204  G06009940   32248.759395
# 1569    5212509.0  +38.4946474  -121.6771343  G06010620  112930.981131
# 1575    7543649.0  +38.4018724  -121.7952918  G06011280  125618.635168
# 1582    5006014.0  +38.4413328  -121.2711972  G06012330  174034.966877
# 1583    2517858.0  +37.8399065  -122.2989635  G06012630   13553.413098
# 1584    1652933.0  +37.8855347  -121.0241489  G06012840  115267.911061
# 1586  112865467.0  +38.2073034  -122.0296674  G06013360  286911.534891
# 1589    7314809.0  +38.6174796  -121.1845995  G06013890   96320.825096
# 1593   26291597.0  +37.4944613  -121.9411499  G06014400  137552.191538
# 1603   20824381.0  +37.6379509  -122.1010098  G06016740   56386.117393
# 1609    8760242.0  +38.0320857  -122.2234423  G06018990   42300.612072
# 1617  195033469.0  +37.2256503  -122.2975334  G06020220  119593.710327
# 1623    2402345.0  +37.9995651  -121.3622008  G06021690   44006.960627
# ...           ...          ...           ...        ...            ...
# 1664      60526.0  +37.5045144  -122.0329158  G06027060   30985.325892
# 1665    1462584.0  +37.3260075  -121.1936646  G06027200  161474.872686
# 1669   65184752.0  +38.0982704  -122.5403661  G06027720   71772.288599
# 1671   56897826.0  +37.7698464  -122.2256900  G06028050  126079.775686
# 1679    1786844.0  +37.4095181  -122.1493751  G06029610   59499.824439
# 1686    2631591.0  +37.4975520  -121.3425653  G06030030  214476.096230
# 1687          0.0  +37.8225436  -122.2300249  G06030330    9644.820643
# 1689    8667646.0  +38.0027878  -121.8893695  G06030600   66739.280951
# 1700  115378750.0  +37.9730280  -122.3310035  G06032550  109043.247032
# 1702    1162294.0  +37.7788996  -121.1341904  G06032880   94823.087143
# 1703   74053138.0  +38.2150530  -121.6757975  G06033110  325021.815215
# 1707    4937983.0  +38.5266112  -121.4544188  G06033840  100276.675892
# 1711  479136515.0  +37.7272391  -123.0322294  G06034410  155020.222734
# 1714     571701.0  +37.2623912  -121.8658513  G06034590  106276.987180
# 1715    2854505.0  +38.6486140  -121.3066981  G06034620   78775.489638
# 1716    5679338.0  +37.7069948  -122.1663168  G06034680   46282.121396
# 1717   14683602.0  +37.6671133  -122.1485865  G06034710   38199.514551
# 1718     737895.0  +37.1408751  -122.1152795  G06034740   89480.913927
# 1723      72161.0  +37.8046693  -121.9365298  G06035130   76644.294902
# 1726    3838063.0  +37.4016881  -121.9733927  G06035430  102138.464583
# 1730  436990440.0  +38.1855080  -122.9483652  G06036670  366519.191170
# 1738    1994246.0  +38.2908198  -122.4703247  G06037200  103327.620563
# 1740   38401356.0  +37.6551037  -122.3762341  G06037530   42217.881937
# 1744   81128373.0  +38.5954891  -122.3199583  G06037830  315113.356008
# 1745    3253362.0  +37.9553945  -121.2702579  G06038010   88190.926673
# 1752     917513.0  +38.2822211  -121.9247148  G06039630   51213.373316
# 1757    1084669.0  +38.3823938  -121.9873549  G06040590   95944.704518
# 1758   64975434.0  +38.1132602  -122.2815836  G06040740  101834.502318
# 1770     980301.0  +38.5688660  -122.0797813  G06042930   98552.964618
# 1771    8975161.0  +38.7201907  -121.7710472  G06043080  174546.217131
#
#         Shape_Area % Total Po  \
# 1453  3.542606e+07      51.76
# 1454  1.028520e+08      94.96
# 1455  2.471326e+08      80.49
# 1465  7.998163e+07      76.75
# 1467  9.877155e+07      45.17
# 1474  1.461159e+08      76.54
# 1477  5.316333e+08      60.11
# 1497  1.154717e+08      57.54
# 1500  6.091217e+07      40.11
# 1506  2.722580e+07      49.11
# 1507  4.634308e+06      54.15
# 1513  1.033205e+08      51.51
# 1525  8.361643e+07      73.08
# 1526  2.732964e+07      62.24
# 1537  2.776186e+08      80.89
# 1541  2.432201e+08      80.71
# 1546  1.816619e+08      58.48
# 1565  3.858397e+07      76.78
# 1569  3.350222e+08      62.37
# 1575  5.117180e+08      73.29
# 1582  8.552628e+08      43.57
# 1583  3.317306e+06      47.87
# 1584  4.174018e+08      85.58
# 1586  6.390225e+08      44.81
# 1589  2.394293e+08      67.38
# 1593  2.006818e+08      29.27
# 1603  8.396272e+07      42.15
# 1609  5.277634e+07      55.98
# 1617  3.533843e+08      90.43
# 1623  3.222720e+07      97.58
# ...            ...        ...
# 1664  3.617711e+07      37.89
# 1665  9.631140e+08       84.9
# 1669  1.558529e+08      79.43
# 1671  1.456602e+08      39.72
# 1679  7.138010e+07      61.94
# 1686  9.344629e+08      73.62
# 1687  4.402171e+06      74.32
# 1689  6.779526e+07      90.12
# 1700  1.618293e+08      46.72
# 1702  1.408012e+08      88.61
# 1703  9.072881e+08      75.98
# 1707  1.801556e+08      56.47
# 1711  1.232103e+08       35.2
# 1714  1.232198e+08      58.13
# 1715  1.996483e+08      94.15
# 1716  3.008090e+07      43.07
# 1717  2.858116e+07      48.96
# 1718  2.365025e+08      92.23
# 1723  2.767926e+08      65.48
# 1726  1.063069e+08      46.33
# 1730  6.153625e+08         80
# 1738  3.136477e+08      82.71
# 1740  2.949232e+07       35.2
# 1744  8.120616e+08      82.07
# 1745  1.496464e+08      95.76
# 1752  1.156884e+08      53.22
# 1757  2.700658e+08      71.32
# 1758  1.100767e+08      42.33
# 1770  3.323597e+08      72.64
# 1771  8.081760e+08      70.86
#
#                                                geometry
# 1453  (POLYGON ((-2235995.2443 329544.7997999992, -2...
# 1454  POLYGON ((-2229697.0096 327679.7281999998, -22...
# 1455  POLYGON ((-2228584.443600001 317234.8045000006...
# 1465  POLYGON ((-2280226.1634 445700.2112000007, -22...
# 1467  POLYGON ((-2175513.788799999 428829.7045000009...
# 1474  POLYGON ((-2284174.1231 457923.0056999996, -22...
# 1477  (POLYGON ((-2194139.802200001 359195.215800000...
# 1497  (POLYGON ((-2167406.512 419634.0886000004, -21...
# 1500  POLYGON ((-2201557.5886 333380.8332000002, -22...
# 1506  (POLYGON ((-2262129.186799999 342248.051699999...
# 1507  POLYGON ((-2260526.694399999 359333.9395000003...
# 1513  (POLYGON ((-2219432.0165 362455.9824999999, -2...
# 1525  POLYGON ((-2235598.247099999 378198.1832999997...
# 1526  POLYGON ((-2258010.686899999 358417.7525999993...
# 1537  POLYGON ((-2277055.568700001 301214.8978000004...
# 1541  (POLYGON ((-2256486.6798 433436.3269999996, -2...
# 1546  POLYGON ((-2244880.855900001 343345.3857000005...
# 1565  POLYGON ((-2283951.274599999 419968.1092000008...
# 1569  POLYGON ((-2183894.052100001 418404.6523000002...
# 1575  POLYGON ((-2205567.675799999 418361.6373999994...
# 1582  POLYGON ((-2159231.722100001 405776.9113999996...
# 1583  POLYGON ((-2262169.084899999 354126.2006999999...
# 1584  POLYGON ((-2142865.9977 340620.7356000002, -21...
# 1586  (POLYGON ((-2225191.3532 367111.4077000003, -2...
# 1589  POLYGON ((-2140512.8462 420640.3264000006, -21...
# 1593  (POLYGON ((-2247215.330800001 305414.314999999...
# 1603  POLYGON ((-2245737.1281 324064.0536000002, -22...
# 1609  POLYGON ((-2245820.6942 369833.1572999991, -22...
# 1617  (POLYGON ((-2289032.217700001 275493.748500000...
# 1623  (POLYGON ((-2174226.4231 347029.7091000006, -2...
# ...                                                 ...
# 1664  POLYGON ((-2248367.9991 313422.1482999995, -22...
# 1665  POLYGON ((-2168452.7107 281652.1085999999, -21...
# 1669  POLYGON ((-2281656.340299999 398281.0997000001...
# 1671  (POLYGON ((-2258316.627699999 337234.1908, -22...
# 1679  (POLYGON ((-2257591.7948 306527.7954999991, -2...
# 1686  POLYGON ((-2175743.5601 301724.6655000001, -21...
# 1687  POLYGON ((-2258972.5386 350894.2634999994, -22...
# 1689  (POLYGON ((-2220386.3455 365440.4097000007, -2...
# 1700  (POLYGON ((-2267757.8233 361454.8627000004, -2...
# 1702  POLYGON ((-2157816.653000001 314383.0259000007...
# 1703  (POLYGON ((-2215124.4882 361054.0697000008, -2...
# 1707  POLYGON ((-2167132.649800001 414429.0556000005...
# 1711  (POLYGON ((-2272574.408399999 346623.860999999...
# 1714  POLYGON ((-2238803.293 272975.5241, -2238763.6...
# 1715  POLYGON ((-2144822.364800001 422123.5492000002...
# 1716  POLYGON ((-2251859.855699999 337206.9690000005...
# 1717  POLYGON ((-2250936.470699999 332097.3003000002...
# 1718  POLYGON ((-2269535.7875 283998.6740000006, -22...
# 1723  POLYGON ((-2223997.9202 342925.0000999998, -22...
# 1726  (POLYGON ((-2249350.423 289361.3359999992, -22...
# 1730  (POLYGON ((-2309325.2081 412073.8903000001, -2...
# 1738  POLYGON ((-2261741.4738 420753.6270000003, -22...
# 1740  (POLYGON ((-2277078.4189 333944.8653999995, -2...
# 1744  (POLYGON ((-2264230.603599999 437929.174399999...
# 1745  POLYGON ((-2170975.282500001 347048.5033999998...
# 1752  POLYGON ((-2210620.5044 393778.0342999995, -22...
# 1757  POLYGON ((-2216439.7926 414003.5238000005, -22...
# 1758  (POLYGON ((-2251211.720699999 386572.5581, -22...
# 1770  POLYGON ((-2208763.0843 430452.2940999996, -22...
# 1771  POLYGON ((-2191566.731899999 454425.6618000008...
#
# [70 rows x 172 columns]

# %%
refresh_data() # Refresh data and undo Bay Area bounding box

# Remove outliers using ess_lean:
charterDF['ess_lean'] = charterDF['ess_strength'] - charterDF['prog_strength']
charterDF = charterDF.dropna(subset=["ess_lean"])
high = charterDF['ess_lean'].quantile(.98) # Find upper limit of ess_lean (a number)
low = charterDF['ess_lean'].quantile(.02)
charterDF = charterDF[(charterDF['ess_lean'] < high) & (charterDF['ess_lean'] > low)]

# %%
plot('% Total Population: White Alone', False, 'CALIFORNIA', 'ca')
# Out:
# /Users/harshayugirase/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
plot('% Total Population: White Alone')
# Out:
# /Users/harshayugirase/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
plot('% Total Population: White Alone')
# Out:
# /Users/harshayugirase/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
plot('Total Population: Foreign Born: Not a Citizen')
# Out:
# /Users/harshayugirase/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
